# %%
import base64
import getpass
import json
import os

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# %%
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)

# %%
PROMPT = """
You are given an image of a receipt. Please read the content into JSON format:

```
{
    "menus": [
        {
            "name": <item_name>,
            "count": <purchased_count>,
            "price": <total_price>
        },
        ...
    ],
    "total": <total_price_in_receipt>
}
```

return only in JSON format
"""
IMAGE_PATH = "receipt1.jpg"

with open(IMAGE_PATH, "rb") as f:
    image_bytes = f.read()
encoded = base64.b64encode(image_bytes).decode("utf-8")
data_uri = f"data:image/jpeg;base64,{encoded}"

message = HumanMessage(
    content=[
        {"type": "text", "text": PROMPT},
        {"type": "image_url", "image_url": data_uri},
    ]
)
response = llm.invoke([message])
print(response.content)
# Out:
# ```json
# {
#     "menus": [
#         {
#             "name": "Bintang Bremer",
#             "count": 1,
#             "price": 59000
#         },
#         {
#             "name": "Chicken H-H",
#             "count": 1,
#             "price": 190000
#         },
#         {
#             "name": "Ades",
#             "count": 1,
#             "price": 10000
#         }
#     ],
#     "total": 302016
# }
# ```

# %%
json_string = response.content.replace("```json", "").replace("```", "")
receipt_dict = json.loads(json_string)
receipt_dict
# Out:
# {'menus': [{'name': 'Bintang Bremer', 'count': 1, 'price': 59000},
#   {'name': 'Chicken H-H', 'count': 1, 'price': 190000},
#   {'name': 'Ades', 'count': 1, 'price': 10000}],
#  'total': 302016}
